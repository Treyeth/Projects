# %%
import numpy as np # linear algebra
from numpy import newaxis
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM, GRU
from keras.models import Sequential
from keras import optimizers
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

print ('import completed')
# Out:
# import completed

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Enrol_window = 60

print ('enrol window set to',Enrol_window )
# Out:
# enrol window set to 60

# %%
sc = MinMaxScaler(feature_range=(0,1))
def load_data(datasetname, column, seq_len, normalise_window):
    # A support function to help prepare datasets for an RNN/LSTM/GRU
    data = datasetname.loc[:,column]

    sequence_length = seq_len + 1
    result = []
    for index in range(len(data) - sequence_length):
        result.append(data[index: index + sequence_length])
    
    if normalise_window:
        #result = sc.fit_transform(result)
        result = normalise_windows(result)

    result = np.array(result)

    #Last 10% is used for validation test, first 90% for training
    row = round(0.9 * result.shape[0])
    train = result[:int(row), :]
    np.random.shuffle(train)
    x_train = train[:, :-1]
    y_train = train[:, -1]
    x_test = result[int(row):, :-1]
    y_test = result[int(row):, -1]

    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))  

    return [x_train, y_train, x_test, y_test]

def normalise_windows(window_data):
    # A support function to normalize a dataset
    normalised_data = []
    for window in window_data:
        normalised_window = [((float(p) / float(window[0])) - 1) for p in window]
        normalised_data.append(normalised_window)
    return normalised_data

def predict_sequence_full(model, data, window_size):
    #Shift the window by 1 new prediction each time, re-run predictions on new window
    curr_frame = data[0]
    predicted = []
    for i in range(len(data)):
        predicted.append(model.predict(curr_frame[newaxis,:,:])[0,0])
        curr_frame = curr_frame[1:]
        curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
    return predicted

def predict_sequences_multiple(model, data, window_size, prediction_len):
    #Predict sequence of <prediction_len> steps before shifting prediction run forward by <prediction_len> steps
    prediction_seqs = []
    for i in range(int(len(data)/prediction_len)):
        curr_frame = data[i*prediction_len]
        predicted = []
        for j in range(prediction_len):
            predicted.append(model.predict(curr_frame[newaxis,:,:])[0,0])
            curr_frame = curr_frame[1:]
            curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
        prediction_seqs.append(predicted)
    return prediction_seqs

def plot_results(predicted_data, true_data, model): 
    fig = plt.figure(facecolor='white', figsize = (15,8)) 
    ax = fig.add_subplot(111) 
    ax.plot(true_data, label='Real Evolution')
    if model == "GRU": 
      ax.set_title("Testing Model GRU BET")
    else:
      ax.set_title("Testing Model LSTM BET")
    plt.plot(predicted_data, label='Forecast') 
    plt.legend() 
    plt.show() 
    
def plot_results_multiple(predicted_data, true_data, prediction_len, model):
    fig = plt.figure(facecolor='white', figsize = (15,8))
    ax = fig.add_subplot(111)
    ax.plot(true_data, label='Observed Evolution')
    if model == "GRU": 
      ax.set_title("Forecast GRU BET")
    else:
      ax.set_title("Forecast LSTM BET")
    #Pad the list of predictions to shift it in the graph to it's correct start
    
    for i, data in enumerate(predicted_data):
        padding = [None for p in range(i * prediction_len)]
        plt.plot(padding + data, label='Forecast')
        plt.legend(loc = "lower right", fontsize = 9)
    plt.show()

# %%
dataset = pd.read_csv('/content/drive/My Drive/BET.csv', index_col='Date', parse_dates=['Date'])
dataset.head()
# Out:
#             Close      Open      High       Low    Vol. Change %
# Date
# 2012-02-01   4927  4,887.75  4,947.30  4,887.75  48.18M    0.79%
# 2012-02-02   4930  4,926.51  4,973.29  4,910.93  46.06M    0.06%
# 2012-02-03   5004  4,929.67  5,036.58  4,928.87  56.74M    1.52%
# 2012-02-06   4943  5,004.48  5,042.92  4,872.06  55.36M   -1.24%
# 2012-02-07   4960  4,942.61  4,975.17  4,927.63   7.05M    0.36%

# %%
feature_train, label_train, feature_test, label_test = load_data(dataset, 'Close', Enrol_window, True)

# %%
# The same LSTM model I would like to test, lets see if the sinus prediction results can be matched
# Note: replace LSTM with GRU or RNN if you want to try those

model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(feature_train.shape[1],1)))
model.add(Dropout(0.2))
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=64, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1, activation = "linear"))

model.compile(loss='mse', optimizer='Adam')

print ('model compiled')
# Out:
# model compiled

# %%
b = model.fit(feature_train, label_train, batch_size=512, epochs=70, validation_data = (feature_test, label_test))
# Out:
# Epoch 1/70
# 4/4 [==============================] - 7s 2s/step - loss: 0.0034 - val_loss: 4.0878e-04
# Epoch 2/70
# 4/4 [==============================] - 5s 1s/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 3/70
# 4/4 [==============================] - 6s 1s/step - loss: 0.0012 - val_loss: 4.3087e-04
# Epoch 4/70
# 4/4 [==============================] - 6s 1s/step - loss: 0.0011 - val_loss: 5.6979e-04
# Epoch 5/70
# 4/4 [==============================] - 5s 1s/step - loss: 9.5196e-04 - val_loss: 2.2126e-04
# Epoch 6/70
# 4/4 [==============================] - 5s 1s/step - loss: 7.9683e-04 - val_loss: 3.4226e-04
# Epoch 7/70
# 4/4 [==============================] - 5s 1s/step - loss: 7.4404e-04 - val_loss: 2.4745e-04
# Epoch 8/70
# 4/4 [==============================] - 5s 1s/step - loss: 7.1967e-04 - val_loss: 2.7264e-04
# Epoch 9/70
# 4/4 [==============================] - 5s 1s/step - loss: 6.4089e-04 - val_loss: 2.4438e-04
# Epoch 10/70
# 4/4 [==============================] - 5s 1s/step - loss: 6.2294e-04 - val_loss: 2.3647e-04
# Epoch 11/70
# 4/4 [==============================] - 5s 1s/step - loss: 5.9423e-04 - val_loss: 3.1624e-04
# Epoch 12/70
# 4/4 [==============================] - 5s 1s/step - loss: 5.8645e-04 - val_loss: 2.0914e-04
# Epoch 13/70
# 4/4 [==============================] - 5s 1s/step - loss: 5.5530e-04 - val_loss: 2.8796e-04
# Epoch 14/70
# 4/4 [==============================] - 5s 1s/step - loss: 5.4977e-04 - val_loss: 2.1615e-04
# Epoch 15/70
# 4/4 [==============================] - 5s 1s/step - loss: 5.1223e-04 - val_loss: 2.0927e-04
# Epoch 16/70
# 4/4 [==============================] - 5s 1s/step - loss: 5.3943e-04 - val_loss: 3.8356e-04
# Epoch 17/70
# 4/4 [==============================] - 5s 1s/step - loss: 5.5375e-04 - val_loss: 2.4712e-04
# Epoch 18/70
# 4/4 [==============================] - 5s 1s/step - loss: 5.3398e-04 - val_loss: 1.8566e-04
# Epoch 19/70
# 4/4 [==============================] - 5s 1s/step - loss: 4.8646e-04 - val_loss: 2.6600e-04
# Epoch 20/70
# 4/4 [==============================] - 5s 1s/step - loss: 4.7887e-04 - val_loss: 1.8978e-04
# Epoch 21/70
# 4/4 [==============================] - 5s 1s/step - loss: 4.6413e-04 - val_loss: 1.8393e-04
# Epoch 22/70
# 4/4 [==============================] - 5s 1s/step - loss: 4.6238e-04 - val_loss: 2.0607e-04
# Epoch 23/70
# 4/4 [==============================] - 5s 1s/step - loss: 4.4850e-04 - val_loss: 2.0787e-04
# Epoch 24/70
# 4/4 [==============================] - 5s 1s/step - loss: 4.3662e-04 - val_loss: 1.6362e-04
# Epoch 25/70
# 4/4 [==============================] - 5s 1s/step - loss: 4.4888e-04 - val_loss: 2.1608e-04
# Epoch 26/70
# 4/4 [==============================] - 5s 1s/step - loss: 4.3388e-04 - val_loss: 1.6519e-04
# Epoch 27/70
# 4/4 [==============================] - 5s 1s/step - loss: 4.3638e-04 - val_loss: 1.6881e-04
# Epoch 28/70
# 4/4 [==============================] - 5s 1s/step - loss: 4.3093e-04 - val_loss: 2.0303e-04
# Epoch 29/70
# 4/4 [==============================] - 5s 1s/step - loss: 4.1417e-04 - val_loss: 2.1247e-04
# Epoch 30/70
# 4/4 [==============================] - 5s 1s/step - loss: 4.2186e-04 - val_loss: 1.5322e-04
# Epoch 31/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.9535e-04 - val_loss: 1.4663e-04
# Epoch 32/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.9768e-04 - val_loss: 2.2069e-04
# Epoch 33/70
# 4/4 [==============================] - 5s 1s/step - loss: 4.0552e-04 - val_loss: 1.4836e-04
# Epoch 34/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.7108e-04 - val_loss: 1.4488e-04
# Epoch 35/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.7318e-04 - val_loss: 1.8228e-04
# Epoch 36/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.7648e-04 - val_loss: 1.6071e-04
# Epoch 37/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.6005e-04 - val_loss: 1.3569e-04
# Epoch 38/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.7241e-04 - val_loss: 1.4757e-04
# Epoch 39/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.6741e-04 - val_loss: 2.1041e-04
# Epoch 40/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.7127e-04 - val_loss: 1.2837e-04
# Epoch 41/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.6053e-04 - val_loss: 1.2158e-04
# Epoch 42/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.4691e-04 - val_loss: 1.1921e-04
# Epoch 43/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.6118e-04 - val_loss: 1.7405e-04
# Epoch 44/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.4462e-04 - val_loss: 1.2223e-04
# Epoch 45/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.3149e-04 - val_loss: 1.1353e-04
# Epoch 46/70
# 4/4 [==============================] - 6s 1s/step - loss: 3.3211e-04 - val_loss: 1.4081e-04
# Epoch 47/70
# 4/4 [==============================] - 6s 1s/step - loss: 3.1792e-04 - val_loss: 1.5107e-04
# Epoch 48/70
# 4/4 [==============================] - 6s 1s/step - loss: 3.1944e-04 - val_loss: 1.1871e-04
# Epoch 49/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.1741e-04 - val_loss: 1.2541e-04
# Epoch 50/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.1847e-04 - val_loss: 1.3827e-04
# Epoch 51/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.1676e-04 - val_loss: 1.0751e-04
# Epoch 52/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.0106e-04 - val_loss: 1.5152e-04
# Epoch 53/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.2066e-04 - val_loss: 1.5540e-04
# Epoch 54/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.0418e-04 - val_loss: 1.0067e-04
# Epoch 55/70
# 4/4 [==============================] - 5s 1s/step - loss: 2.9857e-04 - val_loss: 1.0391e-04
# Epoch 56/70
# 4/4 [==============================] - 5s 1s/step - loss: 2.9014e-04 - val_loss: 1.9319e-04
# Epoch 57/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.0256e-04 - val_loss: 1.0859e-04
# Epoch 58/70
# 4/4 [==============================] - 5s 1s/step - loss: 2.9174e-04 - val_loss: 1.2377e-04
# Epoch 59/70
# 4/4 [==============================] - 5s 1s/step - loss: 3.1454e-04 - val_loss: 1.5067e-04
# Epoch 60/70
# 4/4 [==============================] - 5s 1s/step - loss: 2.8657e-04 - val_loss: 1.4538e-04
# Epoch 61/70
# 4/4 [==============================] - 5s 1s/step - loss: 2.8407e-04 - val_loss: 1.1482e-04
# Epoch 62/70
# 4/4 [==============================] - 6s 1s/step - loss: 2.8807e-04 - val_loss: 1.2525e-04
# Epoch 63/70
# 4/4 [==============================] - 5s 1s/step - loss: 2.8401e-04 - val_loss: 1.5063e-04
# Epoch 64/70
# 4/4 [==============================] - 5s 1s/step - loss: 2.7269e-04 - val_loss: 9.5877e-05
# Epoch 65/70
# 4/4 [==============================] - 5s 1s/step - loss: 2.6309e-04 - val_loss: 1.2949e-04
# Epoch 66/70
# 4/4 [==============================] - 5s 1s/step - loss: 2.5835e-04 - val_loss: 9.8013e-05
# Epoch 67/70
# 4/4 [==============================] - 5s 1s/step - loss: 2.5502e-04 - val_loss: 9.0845e-05
# Epoch 68/70
# 4/4 [==============================] - 5s 1s/step - loss: 2.5505e-04 - val_loss: 1.0183e-04
# Epoch 69/70
# 4/4 [==============================] - 5s 1s/step - loss: 2.4812e-04 - val_loss: 9.1717e-05
# Epoch 70/70
# 4/4 [==============================] - 5s 1s/step - loss: 2.4114e-04 - val_loss: 1.0278e-04

# %%
predicted_stock_price = model.predict(feature_test)
plot_results(predicted_stock_price,label_test, model = "LSTM")

# %%
predictions = predict_sequences_multiple(model, feature_test, Enrol_window, 15)
plot_results_multiple(predictions, label_test, 15, model = "LSTM")

# %%
import math
from sklearn.metrics import mean_squared_error
def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# %%
return_rmse(predicted_stock_price,label_test)
# Out:
# The root mean squared error is 0.010138089740478766.

# %%
modelGRU = Sequential()
modelGRU.add(GRU(60, return_sequences=True, input_shape=(feature_train.shape[1],1),activation='tanh'))
modelGRU.add(Dropout(0.2))
modelGRU.add(GRU(60, return_sequences=True,activation='tanh'))
modelGRU.add(Dropout(0.2))
modelGRU.add(GRU(60, return_sequences=True,activation='tanh'))
modelGRU.add(Dropout(0.2))
modelGRU.add(GRU(units=60, return_sequences=False,activation='tanh'))
modelGRU.add(Dropout(0.2))
modelGRU.add(Dense(1, activation = "linear"))

modelGRU.compile(loss='mse', optimizer='adam')

print ('model compiled')
# Out:
# model compiled

# %%
c = modelGRU.fit(feature_train, label_train, batch_size=28, epochs=30, validation_data = (feature_test, label_test))
# Out:
# Epoch 1/30
# 63/63 [==============================] - 9s 143ms/step - loss: 0.0010 - val_loss: 1.2337e-04
# Epoch 2/30
# 63/63 [==============================] - 8s 130ms/step - loss: 4.6323e-04 - val_loss: 1.1113e-04
# Epoch 3/30
# 63/63 [==============================] - 8s 131ms/step - loss: 3.7054e-04 - val_loss: 1.1010e-04
# Epoch 4/30
# 63/63 [==============================] - 8s 127ms/step - loss: 3.9336e-04 - val_loss: 1.0743e-04
# Epoch 5/30
# 63/63 [==============================] - 8s 123ms/step - loss: 3.7196e-04 - val_loss: 8.3296e-05
# Epoch 6/30
# 63/63 [==============================] - 8s 123ms/step - loss: 2.8103e-04 - val_loss: 1.4454e-04
# Epoch 7/30
# 63/63 [==============================] - 8s 125ms/step - loss: 2.6083e-04 - val_loss: 7.2779e-05
# Epoch 8/30
# 63/63 [==============================] - 8s 124ms/step - loss: 2.7060e-04 - val_loss: 1.5963e-04
# Epoch 9/30
# 63/63 [==============================] - 8s 125ms/step - loss: 2.9100e-04 - val_loss: 1.9075e-04
# Epoch 10/30
# 63/63 [==============================] - 8s 127ms/step - loss: 2.3982e-04 - val_loss: 6.9844e-05
# Epoch 11/30
# 63/63 [==============================] - 8s 126ms/step - loss: 2.3283e-04 - val_loss: 6.2523e-05
# Epoch 12/30
# 63/63 [==============================] - 8s 128ms/step - loss: 2.1603e-04 - val_loss: 5.8238e-05
# Epoch 13/30
# 63/63 [==============================] - 8s 125ms/step - loss: 2.0829e-04 - val_loss: 1.4812e-04
# Epoch 14/30
# 63/63 [==============================] - 8s 127ms/step - loss: 2.0802e-04 - val_loss: 7.3337e-05
# Epoch 15/30
# 63/63 [==============================] - 8s 132ms/step - loss: 2.0659e-04 - val_loss: 5.9187e-05
# Epoch 16/30
# 63/63 [==============================] - 8s 127ms/step - loss: 1.8613e-04 - val_loss: 7.4276e-05
# Epoch 17/30
# 63/63 [==============================] - 8s 126ms/step - loss: 1.9217e-04 - val_loss: 2.9303e-04
# Epoch 18/30
# 63/63 [==============================] - 8s 127ms/step - loss: 2.2282e-04 - val_loss: 1.0272e-04
# Epoch 19/30
# 63/63 [==============================] - 8s 126ms/step - loss: 2.2245e-04 - val_loss: 6.7345e-05
# Epoch 20/30
# 63/63 [==============================] - 8s 128ms/step - loss: 1.9501e-04 - val_loss: 5.4831e-05
# Epoch 21/30
# 63/63 [==============================] - 8s 126ms/step - loss: 1.6751e-04 - val_loss: 6.9697e-05
# Epoch 22/30
# 63/63 [==============================] - 8s 126ms/step - loss: 1.8145e-04 - val_loss: 9.2919e-05
# Epoch 23/30
# 63/63 [==============================] - 8s 127ms/step - loss: 1.8877e-04 - val_loss: 7.4042e-05
# Epoch 24/30
# 63/63 [==============================] - 8s 126ms/step - loss: 1.8444e-04 - val_loss: 6.1904e-05
# Epoch 25/30
# 63/63 [==============================] - 8s 128ms/step - loss: 1.8692e-04 - val_loss: 7.7413e-05
# Epoch 26/30
# 63/63 [==============================] - 8s 125ms/step - loss: 1.8018e-04 - val_loss: 6.8916e-05
# Epoch 27/30
# 63/63 [==============================] - 8s 127ms/step - loss: 1.5830e-04 - val_loss: 7.9123e-05
# Epoch 28/30
# 63/63 [==============================] - 8s 125ms/step - loss: 1.7867e-04 - val_loss: 7.5017e-05
# Epoch 29/30
# 63/63 [==============================] - 8s 127ms/step - loss: 1.7928e-04 - val_loss: 7.7634e-05
# Epoch 30/30
# 63/63 [==============================] - 8s 127ms/step - loss: 1.9041e-04 - val_loss: 4.9470e-05

# %%
predicted_GRU_stock_price = modelGRU.predict(feature_test)
plot_results(predicted_GRU_stock_price,label_test, model = "GRU")

# %%
predicted_GRU_stock_price
# Out:
# array([[0.15898947],
#        [0.17478788],
#        [0.1919412 ],
#        [0.20940518],
#        [0.18782277],
#        [0.20500295],
#        [0.19753923],
#        [0.15764807],
#        [0.14105393],
#        [0.13503401],
#        [0.1141054 ],
#        [0.11462472],
#        [0.13724554],
#        [0.10510665],
#        [0.08309364],
#        [0.07214995],
#        [0.0651708 ],
#        [0.05474035],
#        [0.06391311],
#        [0.06246735],
#        [0.04610948],
#        [0.05184237],
#        [0.04660006],
#        [0.04524169],
#        [0.06834015],
#        [0.07421885],
#        [0.10599007],
#        [0.08598925],
#        [0.06273181],
#        [0.07215019],
#        [0.09016645],
#        [0.08211368],
#        [0.08454883],
#        [0.09125565],
#        [0.0925549 ],
#        [0.09308474],
#        [0.09841749],
#        [0.0913073 ],
#        [0.06940025],
#        [0.06209401],
#        [0.06103895],
#        [0.06929291],
#        [0.08987767],
#        [0.08669931],
#        [0.06423369],
#        [0.06333803],
#        [0.07597119],
#        [0.07441255],
#        [0.08194497],
#        [0.07922482],
#        [0.0749245 ],
#        [0.07847041],
#        [0.08102854],
#        [0.0801602 ],
#        [0.0707513 ],
#        [0.07050248],
#        [0.07653043],
#        [0.09023541],
#        [0.10185412],
#        [0.10496283],
#        [0.10266472],
#        [0.08964124],
#        [0.07926288],
#        [0.08823019],
#        [0.08300479],
#        [0.07828481],
#        [0.06034843],
#        [0.0628269 ],
#        [0.06332672],
#        [0.07458496],
#        [0.06970516],
#        [0.09760991],
#        [0.10023692],
#        [0.09302124],
#        [0.10596499],
#        [0.11293091],
#        [0.10992847],
#        [0.11086409],
#        [0.11252847],
#        [0.11035722],
#        [0.11868164],
#        [0.11708461],
#        [0.11541858],
#        [0.10870916],
#        [0.10050339],
#        [0.07579094],
#        [0.07707235],
#        [0.08351092],
#        [0.06683046],
#        [0.0775798 ],
#        [0.09187984],
#        [0.07332888],
#        [0.07200444],
#        [0.08043386],
#        [0.07845889],
#        [0.07384222],
#        [0.07810864],
#        [0.09172544],
#        [0.08723488],
#        [0.08375038],
#        [0.07657535],
#        [0.06494575],
#        [0.0569959 ],
#        [0.07734516],
#        [0.07929358],
#        [0.07706688],
#        [0.07019286],
#        [0.07109348],
#        [0.08401632],
#        [0.08177589],
#        [0.07475506],
#        [0.06929063],
#        [0.07109351],
#        [0.0795116 ],
#        [0.07352206],
#        [0.06348103],
#        [0.04705084],
#        [0.04085063],
#        [0.04466235],
#        [0.0416454 ],
#        [0.04767648],
#        [0.04873754],
#        [0.04957079],
#        [0.05328362],
#        [0.05404443],
#        [0.06748045],
#        [0.06642658],
#        [0.06606682],
#        [0.06556408],
#        [0.07042672],
#        [0.0464744 ],
#        [0.05623711],
#        [0.06765267],
#        [0.07465059],
#        [0.07417682],
#        [0.06606644],
#        [0.04683005],
#        [0.05157552],
#        [0.06168662],
#        [0.06259958],
#        [0.07111354],
#        [0.07245428],
#        [0.06902263],
#        [0.07371865],
#        [0.06159692],
#        [0.06772333],
#        [0.06730568],
#        [0.07301246],
#        [0.0516175 ],
#        [0.05149246],
#        [0.05421404],
#        [0.05333377],
#        [0.05096165],
#        [0.05773517],
#        [0.05873054],
#        [0.06763652],
#        [0.06836336],
#        [0.07122425],
#        [0.07378609],
#        [0.07174446],
#        [0.07902429],
#        [0.07977244],
#        [0.07482159],
#        [0.07397534],
#        [0.06283468],
#        [0.05086666],
#        [0.03843314],
#        [0.0366486 ],
#        [0.05158706],
#        [0.04272497],
#        [0.04108991],
#        [0.03196899],
#        [0.03454123],
#        [0.03603698],
#        [0.05635466],
#        [0.05905804],
#        [0.05265855],
#        [0.03593656],
#        [0.04372916],
#        [0.03841869],
#        [0.04940008],
#        [0.0458982 ],
#        [0.05359895],
#        [0.05229928],
#        [0.06047043],
#        [0.05522976],
#        [0.05835187],
#        [0.0548887 ],
#        [0.05060425],
#        [0.05438426],
#        [0.06240917],
#        [0.04660323],
#        [0.04407526],
#        [0.03724889]], dtype=float32)

# %%
predictions_GRU = predict_sequences_multiple(modelGRU, feature_test, Enrol_window, 15)
plot_results_multiple(predictions_GRU, label_test, 15, model = "GRU")

# %%
return_rmse(predicted_GRU_stock_price,label_test)
# Out:
# The root mean squared error is 0.007033488255398758.

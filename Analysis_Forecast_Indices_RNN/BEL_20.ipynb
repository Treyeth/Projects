# %%
import numpy as np # linear algebra
from numpy import newaxis
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM, GRU
from keras.models import Sequential
from keras import optimizers
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

print ('import completed')
# Out:
# import completed

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Enrol_window = 60

print ('enrol window set to',Enrol_window )
# Out:
# enrol window set to 60

# %%
sc = MinMaxScaler(feature_range=(0,1))
def load_data(datasetname, column, seq_len, normalise_window):
    # A support function to help prepare datasets for an RNN/LSTM/GRU
    data = datasetname.loc[:,column]

    sequence_length = seq_len + 1
    result = []
    for index in range(len(data) - sequence_length):
        result.append(data[index: index + sequence_length])
    
    if normalise_window:
        #result = sc.fit_transform(result)
        result = normalise_windows(result)

    result = np.array(result)

    #Last 10% is used for validation test, first 90% for training
    row = round(0.9 * result.shape[0])
    train = result[:int(row), :]
    np.random.shuffle(train)
    x_train = train[:, :-1]
    y_train = train[:, -1]
    x_test = result[int(row):, :-1]
    y_test = result[int(row):, -1]

    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))  

    return [x_train, y_train, x_test, y_test]

def normalise_windows(window_data):
    # A support function to normalize a dataset
    normalised_data = []
    for window in window_data:
        normalised_window = [((float(p) / float(window[0])) - 1) for p in window]
        normalised_data.append(normalised_window)
    return normalised_data

def predict_sequence_full(model, data, window_size):
    #Shift the window by 1 new prediction each time, re-run predictions on new window
    curr_frame = data[0]
    predicted = []
    for i in range(len(data)):
        predicted.append(model.predict(curr_frame[newaxis,:,:])[0,0])
        curr_frame = curr_frame[1:]
        curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
    return predicted

def predict_sequences_multiple(model, data, window_size, prediction_len):
    #Predict sequence of <prediction_len> steps before shifting prediction run forward by <prediction_len> steps
    prediction_seqs = []
    for i in range(int(len(data)/prediction_len)):
        curr_frame = data[i*prediction_len]
        predicted = []
        for j in range(prediction_len):
            predicted.append(model.predict(curr_frame[newaxis,:,:])[0,0])
            curr_frame = curr_frame[1:]
            curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
        prediction_seqs.append(predicted)
    return prediction_seqs

def plot_results(predicted_data, true_data, model): 
    fig = plt.figure(facecolor = 'white', figsize = (15,8)) 
    ax = fig.add_subplot(111) 
    ax.plot(true_data, label='Real Evolution')
    if model == "GRU": 
      ax.set_title("Testing Model GRU BEL 20")
    else:
      ax.set_title("Testing Model LSTM BEL 20")
    plt.plot(predicted_data, label = 'Forecast') 
    plt.legend() 
    plt.show() 
    
def plot_results_multiple(predicted_data, true_data, prediction_len, model):
    fig = plt.figure(facecolor='white', figsize = (15,8))
    ax = fig.add_subplot(111)
    ax.plot(true_data, label='Observed Evolution')
    if model == "GRU": 
      ax.set_title("Forecast GRU BEL 20")
    else:
      ax.set_title("Forecast LSTM BEL 20")
    #Pad the list of predictions to shift it in the graph to it's correct start
    
    for i, data in enumerate(predicted_data):
        padding = [None for p in range(i * prediction_len)]
        plt.plot(padding + data, label='Forecast')
        plt.legend(loc = "lower right", fontsize = 9)
    plt.show()
print ('Support functions defined')
# Out:
# Support functions defined

# %%
dataset = pd.read_csv('/content/drive/My Drive/BEL_20.csv', index_col='Date', parse_dates=['Date'])
dataset.head()
# Out:
#             Close      Open      High       Low    Vol. Change %
# Date
# 2012-02-01   2265  2,210.04  2,264.73  2,210.04  26.74M    2.63%
# 2012-02-02   2272  2,271.84  2,278.02  2,255.19  30.50M    0.33%
# 2012-02-03   2305  2,268.53  2,304.58  2,263.61  23.85M    1.43%
# 2012-02-06   2288  2,297.77  2,297.77  2,271.83  20.64M   -0.70%
# 2012-02-07   2286  2,295.18  2,299.80  2,270.46  15.89M   -0.09%

# %%
feature_train, label_train, feature_test, label_test = load_data(dataset, 'Close', Enrol_window, True)

# %%
# The same LSTM model I would like to test, lets see if the sinus prediction results can be matched
# Note: replace LSTM with GRU or RNN if you want to try those

model = Sequential()
model.add(LSTM(60, return_sequences=True, input_shape=(feature_train.shape[1],1)))
model.add(Dropout(0.2))
model.add(LSTM(60, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(60, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=60, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1, activation = "linear"))

model.compile(loss='mse', optimizer='adam')

print ('model compiled')
# Out:
# model compiled

# %%
b = model.fit(feature_train, label_train, batch_size=128, epochs=100, validation_data = (feature_test, label_test))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 5s 352ms/step - loss: 0.0016 - val_loss: 8.4876e-04
# Epoch 2/100
# 14/14 [==============================] - 4s 250ms/step - loss: 8.1579e-04 - val_loss: 7.0221e-04
# Epoch 3/100
# 14/14 [==============================] - 4s 253ms/step - loss: 7.0693e-04 - val_loss: 6.0550e-04
# Epoch 4/100
# 14/14 [==============================] - 3s 247ms/step - loss: 6.8612e-04 - val_loss: 5.3833e-04
# Epoch 5/100
# 14/14 [==============================] - 3s 248ms/step - loss: 6.1020e-04 - val_loss: 5.0411e-04
# Epoch 6/100
# 14/14 [==============================] - 4s 253ms/step - loss: 5.5307e-04 - val_loss: 4.6775e-04
# Epoch 7/100
# 14/14 [==============================] - 4s 253ms/step - loss: 5.2390e-04 - val_loss: 4.1796e-04
# Epoch 8/100
# 14/14 [==============================] - 4s 256ms/step - loss: 4.9675e-04 - val_loss: 3.8965e-04
# Epoch 9/100
# 14/14 [==============================] - 4s 251ms/step - loss: 4.6760e-04 - val_loss: 4.1399e-04
# Epoch 10/100
# 14/14 [==============================] - 3s 246ms/step - loss: 4.5582e-04 - val_loss: 3.9206e-04
# Epoch 11/100
# 14/14 [==============================] - 3s 247ms/step - loss: 4.3126e-04 - val_loss: 3.4288e-04
# Epoch 12/100
# 14/14 [==============================] - 3s 248ms/step - loss: 4.0279e-04 - val_loss: 3.1607e-04
# Epoch 13/100
# 14/14 [==============================] - 3s 245ms/step - loss: 3.8920e-04 - val_loss: 4.0771e-04
# Epoch 14/100
# 14/14 [==============================] - 4s 251ms/step - loss: 4.0812e-04 - val_loss: 4.1175e-04
# Epoch 15/100
# 14/14 [==============================] - 3s 244ms/step - loss: 3.7901e-04 - val_loss: 2.9582e-04
# Epoch 16/100
# 14/14 [==============================] - 4s 253ms/step - loss: 3.4444e-04 - val_loss: 2.6718e-04
# Epoch 17/100
# 14/14 [==============================] - 4s 255ms/step - loss: 3.3579e-04 - val_loss: 2.6206e-04
# Epoch 18/100
# 14/14 [==============================] - 4s 256ms/step - loss: 3.2597e-04 - val_loss: 2.9774e-04
# Epoch 19/100
# 14/14 [==============================] - 4s 254ms/step - loss: 3.4110e-04 - val_loss: 2.2420e-04
# Epoch 20/100
# 14/14 [==============================] - 3s 247ms/step - loss: 3.0363e-04 - val_loss: 2.5829e-04
# Epoch 21/100
# 14/14 [==============================] - 3s 246ms/step - loss: 2.9938e-04 - val_loss: 2.3359e-04
# Epoch 22/100
# 14/14 [==============================] - 4s 252ms/step - loss: 2.8766e-04 - val_loss: 2.4109e-04
# Epoch 23/100
# 14/14 [==============================] - 4s 254ms/step - loss: 2.9152e-04 - val_loss: 2.0394e-04
# Epoch 24/100
# 14/14 [==============================] - 3s 249ms/step - loss: 2.7180e-04 - val_loss: 2.2088e-04
# Epoch 25/100
# 14/14 [==============================] - 4s 252ms/step - loss: 2.8396e-04 - val_loss: 2.1415e-04
# Epoch 26/100
# 14/14 [==============================] - 3s 248ms/step - loss: 2.6976e-04 - val_loss: 1.8945e-04
# Epoch 27/100
# 14/14 [==============================] - 4s 252ms/step - loss: 2.6154e-04 - val_loss: 1.9316e-04
# Epoch 28/100
# 14/14 [==============================] - 3s 249ms/step - loss: 2.6115e-04 - val_loss: 1.8119e-04
# Epoch 29/100
# 14/14 [==============================] - 4s 253ms/step - loss: 2.5288e-04 - val_loss: 2.0378e-04
# Epoch 30/100
# 14/14 [==============================] - 3s 250ms/step - loss: 2.5193e-04 - val_loss: 1.8904e-04
# Epoch 31/100
# 14/14 [==============================] - 4s 252ms/step - loss: 2.2701e-04 - val_loss: 1.6390e-04
# Epoch 32/100
# 14/14 [==============================] - 4s 254ms/step - loss: 2.4204e-04 - val_loss: 1.5833e-04
# Epoch 33/100
# 14/14 [==============================] - 4s 252ms/step - loss: 2.3736e-04 - val_loss: 1.5993e-04
# Epoch 34/100
# 14/14 [==============================] - 4s 257ms/step - loss: 2.3004e-04 - val_loss: 1.5979e-04
# Epoch 35/100
# 14/14 [==============================] - 4s 256ms/step - loss: 2.1516e-04 - val_loss: 1.5902e-04
# Epoch 36/100
# 14/14 [==============================] - 4s 253ms/step - loss: 2.1334e-04 - val_loss: 1.5048e-04
# Epoch 37/100
# 14/14 [==============================] - 4s 259ms/step - loss: 2.1168e-04 - val_loss: 1.4282e-04
# Epoch 38/100
# 14/14 [==============================] - 4s 256ms/step - loss: 2.0458e-04 - val_loss: 1.4130e-04
# Epoch 39/100
# 14/14 [==============================] - 4s 261ms/step - loss: 1.9941e-04 - val_loss: 1.2805e-04
# Epoch 40/100
# 14/14 [==============================] - 4s 258ms/step - loss: 1.9770e-04 - val_loss: 1.5048e-04
# Epoch 41/100
# 14/14 [==============================] - 4s 253ms/step - loss: 1.8707e-04 - val_loss: 1.4995e-04
# Epoch 42/100
# 14/14 [==============================] - 4s 256ms/step - loss: 1.9060e-04 - val_loss: 1.2199e-04
# Epoch 43/100
# 14/14 [==============================] - 4s 259ms/step - loss: 1.8693e-04 - val_loss: 1.2936e-04
# Epoch 44/100
# 14/14 [==============================] - 4s 256ms/step - loss: 1.8539e-04 - val_loss: 1.3068e-04
# Epoch 45/100
# 14/14 [==============================] - 4s 260ms/step - loss: 2.0150e-04 - val_loss: 1.1342e-04
# Epoch 46/100
# 14/14 [==============================] - 4s 253ms/step - loss: 1.7403e-04 - val_loss: 1.1310e-04
# Epoch 47/100
# 14/14 [==============================] - 4s 251ms/step - loss: 1.6805e-04 - val_loss: 1.1610e-04
# Epoch 48/100
# 14/14 [==============================] - 4s 252ms/step - loss: 1.6989e-04 - val_loss: 1.1712e-04
# Epoch 49/100
# 14/14 [==============================] - 4s 252ms/step - loss: 1.7068e-04 - val_loss: 1.0942e-04
# Epoch 50/100
# 14/14 [==============================] - 4s 252ms/step - loss: 1.6735e-04 - val_loss: 1.0296e-04
# Epoch 51/100
# 14/14 [==============================] - 4s 251ms/step - loss: 1.5958e-04 - val_loss: 1.1063e-04
# Epoch 52/100
# 14/14 [==============================] - 4s 252ms/step - loss: 1.5886e-04 - val_loss: 1.0074e-04
# Epoch 53/100
# 14/14 [==============================] - 4s 252ms/step - loss: 1.4652e-04 - val_loss: 9.5367e-05
# Epoch 54/100
# 14/14 [==============================] - 4s 252ms/step - loss: 1.5187e-04 - val_loss: 9.7911e-05
# Epoch 55/100
# 14/14 [==============================] - 4s 254ms/step - loss: 1.5216e-04 - val_loss: 1.1345e-04
# Epoch 56/100
# 14/14 [==============================] - 4s 253ms/step - loss: 1.5559e-04 - val_loss: 9.9032e-05
# Epoch 57/100
# 14/14 [==============================] - 4s 251ms/step - loss: 1.5538e-04 - val_loss: 9.1862e-05
# Epoch 58/100
# 14/14 [==============================] - 3s 249ms/step - loss: 1.7130e-04 - val_loss: 9.0323e-05
# Epoch 59/100
# 14/14 [==============================] - 4s 253ms/step - loss: 1.5338e-04 - val_loss: 8.8043e-05
# Epoch 60/100
# 14/14 [==============================] - 4s 258ms/step - loss: 1.4772e-04 - val_loss: 9.3137e-05
# Epoch 61/100
# 14/14 [==============================] - 4s 256ms/step - loss: 1.4502e-04 - val_loss: 9.1654e-05
# Epoch 62/100
# 14/14 [==============================] - 4s 260ms/step - loss: 1.4064e-04 - val_loss: 8.7313e-05
# Epoch 63/100
# 14/14 [==============================] - 4s 259ms/step - loss: 1.5974e-04 - val_loss: 9.4885e-05
# Epoch 64/100
# 14/14 [==============================] - 4s 255ms/step - loss: 1.4588e-04 - val_loss: 8.3320e-05
# Epoch 65/100
# 14/14 [==============================] - 4s 255ms/step - loss: 1.4016e-04 - val_loss: 8.3765e-05
# Epoch 66/100
# 14/14 [==============================] - 4s 251ms/step - loss: 1.5423e-04 - val_loss: 9.5235e-05
# Epoch 67/100
# 14/14 [==============================] - 4s 259ms/step - loss: 1.4498e-04 - val_loss: 8.4242e-05
# Epoch 68/100
# 14/14 [==============================] - 4s 261ms/step - loss: 1.4314e-04 - val_loss: 8.4606e-05
# Epoch 69/100
# 14/14 [==============================] - 4s 259ms/step - loss: 1.4480e-04 - val_loss: 1.0571e-04
# Epoch 70/100
# 14/14 [==============================] - 4s 256ms/step - loss: 1.4913e-04 - val_loss: 9.6598e-05
# Epoch 71/100
# 14/14 [==============================] - 4s 252ms/step - loss: 1.4661e-04 - val_loss: 8.8747e-05
# Epoch 72/100
# 14/14 [==============================] - 4s 253ms/step - loss: 1.4344e-04 - val_loss: 8.7929e-05
# Epoch 73/100
# 14/14 [==============================] - 4s 262ms/step - loss: 1.4140e-04 - val_loss: 8.0537e-05
# Epoch 74/100
# 14/14 [==============================] - 4s 251ms/step - loss: 1.3985e-04 - val_loss: 9.4607e-05
# Epoch 75/100
# 14/14 [==============================] - 4s 254ms/step - loss: 1.3689e-04 - val_loss: 8.0320e-05
# Epoch 76/100
# 14/14 [==============================] - 4s 252ms/step - loss: 1.4380e-04 - val_loss: 8.1104e-05
# Epoch 77/100
# 14/14 [==============================] - 4s 251ms/step - loss: 1.4149e-04 - val_loss: 8.4092e-05
# Epoch 78/100
# 14/14 [==============================] - 4s 253ms/step - loss: 1.4549e-04 - val_loss: 8.4969e-05
# Epoch 79/100
# 14/14 [==============================] - 4s 257ms/step - loss: 1.4702e-04 - val_loss: 9.2883e-05
# Epoch 80/100
# 14/14 [==============================] - 4s 254ms/step - loss: 1.4626e-04 - val_loss: 8.0835e-05
# Epoch 81/100
# 14/14 [==============================] - 4s 256ms/step - loss: 1.3796e-04 - val_loss: 8.2041e-05
# Epoch 82/100
# 14/14 [==============================] - 4s 253ms/step - loss: 1.4078e-04 - val_loss: 1.0369e-04
# Epoch 83/100
# 14/14 [==============================] - 4s 253ms/step - loss: 1.3137e-04 - val_loss: 8.3855e-05
# Epoch 84/100
# 14/14 [==============================] - 4s 254ms/step - loss: 1.4099e-04 - val_loss: 7.8142e-05
# Epoch 85/100
# 14/14 [==============================] - 4s 255ms/step - loss: 1.3232e-04 - val_loss: 7.7572e-05
# Epoch 86/100
# 14/14 [==============================] - 4s 253ms/step - loss: 1.4468e-04 - val_loss: 8.8380e-05
# Epoch 87/100
# 14/14 [==============================] - 4s 250ms/step - loss: 1.3656e-04 - val_loss: 7.8767e-05
# Epoch 88/100
# 14/14 [==============================] - 3s 249ms/step - loss: 1.3576e-04 - val_loss: 7.7826e-05
# Epoch 89/100
# 14/14 [==============================] - 4s 253ms/step - loss: 1.2973e-04 - val_loss: 8.2043e-05
# Epoch 90/100
# 14/14 [==============================] - 4s 253ms/step - loss: 1.3745e-04 - val_loss: 8.2290e-05
# Epoch 91/100
# 14/14 [==============================] - 3s 250ms/step - loss: 1.3299e-04 - val_loss: 7.8755e-05
# Epoch 92/100
# 14/14 [==============================] - 4s 256ms/step - loss: 1.2719e-04 - val_loss: 7.8013e-05
# Epoch 93/100
# 14/14 [==============================] - 3s 248ms/step - loss: 1.3129e-04 - val_loss: 7.9443e-05
# Epoch 94/100
# 14/14 [==============================] - 4s 251ms/step - loss: 1.2927e-04 - val_loss: 7.6758e-05
# Epoch 95/100
# 14/14 [==============================] - 4s 252ms/step - loss: 1.2799e-04 - val_loss: 8.6605e-05
# Epoch 96/100
# 14/14 [==============================] - 4s 253ms/step - loss: 1.2729e-04 - val_loss: 7.8112e-05
# Epoch 97/100
# 14/14 [==============================] - 4s 252ms/step - loss: 1.2930e-04 - val_loss: 8.1190e-05
# Epoch 98/100
# 14/14 [==============================] - 4s 263ms/step - loss: 1.2053e-04 - val_loss: 8.4056e-05
# Epoch 99/100
# 14/14 [==============================] - 4s 255ms/step - loss: 1.3577e-04 - val_loss: 7.6891e-05
# Epoch 100/100
# 14/14 [==============================] - 4s 257ms/step - loss: 1.2977e-04 - val_loss: 7.8176e-05

# %%
# plot history
from matplotlib import pyplot
pyplot.plot(b.history['loss'], label='train')
pyplot.plot(b.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
predicted_stock_price = model.predict(feature_test)
plot_results(predicted_stock_price,label_test)

# %%
predictions = predict_sequences_multiple(model, feature_test, Enrol_window, 15)
plot_results_multiple(predictions, label_test, 15)

# %%
import math
from sklearn.metrics import mean_squared_error
def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# %%
return_rmse(predicted_stock_price,label_test)
# Out:
# The root mean squared error is 0.008841738864919743.

# %%
modelGRU = Sequential()
modelGRU.add(GRU(256, return_sequences=True, input_shape=(feature_train.shape[1],1),activation='tanh'))
modelGRU.add(Dropout(0.2))
modelGRU.add(GRU(256, return_sequences=True,activation='tanh'))
modelGRU.add(Dropout(0.2))
modelGRU.add(GRU(units=64, return_sequences=False,activation='tanh'))
modelGRU.add(Dropout(0.2))
modelGRU.add(Dense(1, activation = "linear"))

modelGRU.compile(loss='mse', optimizer='adam')

print ('model compiled')
# Out:
# model compiled

# %%
c = modelGRU.fit(feature_train, label_train, batch_size = 64, epochs = 30, validation_data = (feature_test, label_test))
# Out:
# Epoch 1/30
# 28/28 [==============================] - 17s 612ms/step - loss: 7.6289e-04 - val_loss: 1.7206e-04
# Epoch 2/30
# 28/28 [==============================] - 16s 588ms/step - loss: 2.6709e-04 - val_loss: 1.8464e-04
# Epoch 3/30
# 28/28 [==============================] - 16s 581ms/step - loss: 2.0958e-04 - val_loss: 1.5699e-04
# Epoch 4/30
# 28/28 [==============================] - 16s 587ms/step - loss: 1.9658e-04 - val_loss: 1.3512e-04
# Epoch 5/30
# 28/28 [==============================] - 16s 588ms/step - loss: 1.8007e-04 - val_loss: 1.1068e-04
# Epoch 6/30
# 28/28 [==============================] - 17s 590ms/step - loss: 1.6280e-04 - val_loss: 9.6361e-05
# Epoch 7/30
# 28/28 [==============================] - 17s 597ms/step - loss: 1.5450e-04 - val_loss: 1.0918e-04
# Epoch 8/30
# 28/28 [==============================] - 17s 596ms/step - loss: 1.4018e-04 - val_loss: 1.1044e-04
# Epoch 9/30
# 28/28 [==============================] - 16s 583ms/step - loss: 1.3981e-04 - val_loss: 9.5092e-05
# Epoch 10/30
# 28/28 [==============================] - 16s 585ms/step - loss: 1.3506e-04 - val_loss: 8.9910e-05
# Epoch 11/30
# 28/28 [==============================] - 17s 595ms/step - loss: 1.5287e-04 - val_loss: 1.0792e-04
# Epoch 12/30
# 28/28 [==============================] - 17s 591ms/step - loss: 1.4017e-04 - val_loss: 7.9240e-05
# Epoch 13/30
# 28/28 [==============================] - 16s 587ms/step - loss: 1.3302e-04 - val_loss: 1.0476e-04
# Epoch 14/30
# 28/28 [==============================] - 16s 587ms/step - loss: 1.4413e-04 - val_loss: 8.0721e-05
# Epoch 15/30
# 28/28 [==============================] - 16s 578ms/step - loss: 1.3267e-04 - val_loss: 8.1410e-05
# Epoch 16/30
# 28/28 [==============================] - 16s 587ms/step - loss: 1.3868e-04 - val_loss: 8.0883e-05
# Epoch 17/30
# 28/28 [==============================] - 16s 584ms/step - loss: 1.3076e-04 - val_loss: 8.8644e-05
# Epoch 18/30
# 28/28 [==============================] - 16s 582ms/step - loss: 1.3559e-04 - val_loss: 8.2181e-05
# Epoch 19/30
# 28/28 [==============================] - 16s 586ms/step - loss: 1.3389e-04 - val_loss: 8.4169e-05
# Epoch 20/30
# 28/28 [==============================] - 16s 584ms/step - loss: 1.3192e-04 - val_loss: 7.8374e-05
# Epoch 21/30
# 28/28 [==============================] - 16s 587ms/step - loss: 1.3295e-04 - val_loss: 7.5477e-05
# Epoch 22/30
# 28/28 [==============================] - 16s 582ms/step - loss: 1.4459e-04 - val_loss: 8.0408e-05
# Epoch 23/30
# 28/28 [==============================] - 16s 580ms/step - loss: 1.6995e-04 - val_loss: 9.1380e-05
# Epoch 24/30
# 28/28 [==============================] - 16s 581ms/step - loss: 1.4081e-04 - val_loss: 7.9364e-05
# Epoch 25/30
# 28/28 [==============================] - 17s 600ms/step - loss: 1.4133e-04 - val_loss: 1.1726e-04
# Epoch 26/30
# 28/28 [==============================] - 16s 580ms/step - loss: 1.3225e-04 - val_loss: 7.8207e-05
# Epoch 27/30
# 28/28 [==============================] - 17s 591ms/step - loss: 1.2774e-04 - val_loss: 9.0410e-05
# Epoch 28/30
# 28/28 [==============================] - 17s 592ms/step - loss: 1.2204e-04 - val_loss: 7.7303e-05
# Epoch 29/30
# 28/28 [==============================] - 17s 591ms/step - loss: 1.2733e-04 - val_loss: 9.5670e-05
# Epoch 30/30
# 28/28 [==============================] - 16s 587ms/step - loss: 1.4838e-04 - val_loss: 7.8010e-05

# %%
predicted_GRU_stock_price = modelGRU.predict(feature_test)
plot_results(predicted_GRU_stock_price,label_test)

# %%
predictions_GRU = predict_sequences_multiple(modelGRU, feature_test, Enrol_window, 15)
plot_results_multiple(predictions_GRU, label_test, 15)

# %%
return_rmse(predicted_GRU_stock_price,label_test)
# Out:
# The root mean squared error is 0.009360780100379787.

# %%
import numpy as np # linear algebra
from numpy import newaxis
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM, GRU
from keras.models import Sequential
from keras import optimizers
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

print ('import completed')
# Out:
# import completed

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Enrol_window = 60

print ('enrol window set to',Enrol_window )
# Out:
# enrol window set to 60

# %%
sc = MinMaxScaler(feature_range=(0,1))
def load_data(datasetname, column, seq_len, normalise_window):
    # A support function to help prepare datasets for an RNN/LSTM/GRU
    data = datasetname.loc[:,column]

    sequence_length = seq_len + 1
    result = []
    for index in range(len(data) - sequence_length):
        result.append(data[index: index + sequence_length])
    
    if normalise_window:
        #result = sc.fit_transform(result)
        result = normalise_windows(result)

    result = np.array(result)

    #Last 10% is used for validation test, first 90% for training
    row = round(0.9 * result.shape[0])
    train = result[:int(row), :]
    np.random.shuffle(train)
    x_train = train[:, :-1]
    y_train = train[:, -1]
    x_test = result[int(row):, :-1]
    y_test = result[int(row):, -1]

    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))  

    return [x_train, y_train, x_test, y_test]

def normalise_windows(window_data):
    # A support function to normalize a dataset
    normalised_data = []
    for window in window_data:
        normalised_window = [((float(p) / float(window[0])) - 1) for p in window]
        normalised_data.append(normalised_window)
    return normalised_data

def predict_sequence_full(model, data, window_size):
    #Shift the window by 1 new prediction each time, re-run predictions on new window
    curr_frame = data[0]
    predicted = []
    for i in range(len(data)):
        predicted.append(model.predict(curr_frame[newaxis,:,:])[0,0])
        curr_frame = curr_frame[1:]
        curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
    return predicted

def predict_sequences_multiple(model, data, window_size, prediction_len):
    #Predict sequence of <prediction_len> steps before shifting prediction run forward by <prediction_len> steps
    prediction_seqs = []
    for i in range(int(len(data)/prediction_len)):
        curr_frame = data[i*prediction_len]
        predicted = []
        for j in range(prediction_len):
            predicted.append(model.predict(curr_frame[newaxis,:,:])[0,0])
            curr_frame = curr_frame[1:]
            curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
        prediction_seqs.append(predicted)
    return prediction_seqs


def plot_results(predicted_data, true_data, model): 
    fig = plt.figure(facecolor='white', figsize = (15,8)) 
    ax = fig.add_subplot(111) 
    ax.plot(true_data, label='Real Evolution')
    if model == "GRU": 
      ax.set_title("Testing Model GRU SMI")
    else:
      ax.set_title("Testing Model LSTM SMI")
    plt.plot(predicted_data, label='Forecast') 
    plt.legend() 
    plt.show() 
    
def plot_results_multiple(predicted_data, true_data, prediction_len, model):
    fig = plt.figure(facecolor='white', figsize = (15,8))
    ax = fig.add_subplot(111)
    ax.plot(true_data, label='Observed Evolution')
    if model == "GRU": 
      ax.set_title("Forecast GRU SMI")
    else:
      ax.set_title("Forecast LSTM SMI")
 
    #Pad the list of predictions to shift it in the graph to it's correct start
    for i, data in enumerate(predicted_data):
        padding = [None for p in range(i * prediction_len)]
        plt.plot(padding + data, label='Forecast')
        plt.legend(loc = "lower right", fontsize = 9)
    plt.show()

print ('Support functions defined')
# Out:
# Support functions defined

# %%
dataset = pd.read_csv('/content/drive/My Drive/SMI.csv', index_col='Date', parse_dates=['Date'])
dataset.head()
# Out:
#             Close      Open      High       Low    Vol. Change %
# Date
# 2012-02-01   6070  5,984.11  6,077.40  5,979.22  55.10M    1.67%
# 2012-02-02   6064  6,083.36  6,085.11  6,038.53  51.60M   -0.09%
# 2012-02-03   6153  6,062.44  6,158.11  6,046.99  55.58M    1.47%
# 2012-02-06   6147  6,126.54  6,150.80  6,103.77  40.33M   -0.10%
# 2012-02-07   6158  6,143.40  6,158.50  6,114.68  51.76M    0.17%

# %%
feature_train, label_train, feature_test, label_test = load_data(dataset, 'Close', Enrol_window, True)

# %%
# The same LSTM model I would like to test, lets see if the sinus prediction results can be matched
# Note: replace LSTM with GRU or RNN if you want to try those

model = Sequential()
model.add(LSTM(256, return_sequences=True, input_shape=(feature_train.shape[1],1)))
model.add(Dropout(0.2))
model.add(LSTM(256, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=64, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1, activation = "linear"))

model.compile(loss='mse', optimizer='adam')

print ('model compiled')
# Out:
# model compiled

# %%
b = model.fit(feature_train, label_train, batch_size=128, epochs=50, validation_data = (feature_test, label_test))
# Out:
# Epoch 1/50
# 14/14 [==============================] - 17s 1s/step - loss: 9.0790e-04 - val_loss: 1.7124e-04
# Epoch 2/50
# 14/14 [==============================] - 15s 1s/step - loss: 4.2887e-04 - val_loss: 1.5806e-04
# Epoch 3/50
# 14/14 [==============================] - 16s 1s/step - loss: 3.5820e-04 - val_loss: 1.4397e-04
# Epoch 4/50
# 14/14 [==============================] - 16s 1s/step - loss: 3.2642e-04 - val_loss: 1.3628e-04
# Epoch 5/50
# 14/14 [==============================] - 16s 1s/step - loss: 2.9439e-04 - val_loss: 1.7202e-04
# Epoch 6/50
# 14/14 [==============================] - 16s 1s/step - loss: 2.8876e-04 - val_loss: 1.2792e-04
# Epoch 7/50
# 14/14 [==============================] - 16s 1s/step - loss: 2.5590e-04 - val_loss: 1.3298e-04
# Epoch 8/50
# 14/14 [==============================] - 16s 1s/step - loss: 2.5133e-04 - val_loss: 1.1913e-04
# Epoch 9/50
# 14/14 [==============================] - 16s 1s/step - loss: 2.3804e-04 - val_loss: 1.2330e-04
# Epoch 10/50
# 14/14 [==============================] - 17s 1s/step - loss: 2.2199e-04 - val_loss: 1.1482e-04
# Epoch 11/50
# 14/14 [==============================] - 16s 1s/step - loss: 2.1407e-04 - val_loss: 1.1401e-04
# Epoch 12/50
# 14/14 [==============================] - 16s 1s/step - loss: 2.0741e-04 - val_loss: 1.0451e-04
# Epoch 13/50
# 14/14 [==============================] - 16s 1s/step - loss: 2.0676e-04 - val_loss: 9.6614e-05
# Epoch 14/50
# 14/14 [==============================] - 16s 1s/step - loss: 2.0397e-04 - val_loss: 9.5771e-05
# Epoch 15/50
# 14/14 [==============================] - 16s 1s/step - loss: 2.0248e-04 - val_loss: 1.1930e-04
# Epoch 16/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.9217e-04 - val_loss: 1.6100e-04
# Epoch 17/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.8144e-04 - val_loss: 1.0242e-04
# Epoch 18/50
# 14/14 [==============================] - 17s 1s/step - loss: 1.7647e-04 - val_loss: 8.8175e-05
# Epoch 19/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.6140e-04 - val_loss: 8.2986e-05
# Epoch 20/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.7080e-04 - val_loss: 8.8036e-05
# Epoch 21/50
# 14/14 [==============================] - 17s 1s/step - loss: 1.6110e-04 - val_loss: 7.8249e-05
# Epoch 22/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.5541e-04 - val_loss: 7.7852e-05
# Epoch 23/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.5432e-04 - val_loss: 8.3539e-05
# Epoch 24/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.4480e-04 - val_loss: 8.3551e-05
# Epoch 25/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.5061e-04 - val_loss: 7.2027e-05
# Epoch 26/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.3807e-04 - val_loss: 7.8887e-05
# Epoch 27/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.3310e-04 - val_loss: 6.9033e-05
# Epoch 28/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.3456e-04 - val_loss: 7.4017e-05
# Epoch 29/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.3937e-04 - val_loss: 6.5411e-05
# Epoch 30/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.2834e-04 - val_loss: 6.7046e-05
# Epoch 31/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.3186e-04 - val_loss: 6.2383e-05
# Epoch 32/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.2791e-04 - val_loss: 5.9610e-05
# Epoch 33/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.3892e-04 - val_loss: 6.0992e-05
# Epoch 34/50
# 14/14 [==============================] - 17s 1s/step - loss: 1.2116e-04 - val_loss: 5.9319e-05
# Epoch 35/50
# 14/14 [==============================] - 18s 1s/step - loss: 1.1655e-04 - val_loss: 5.8229e-05
# Epoch 36/50
# 14/14 [==============================] - 19s 1s/step - loss: 1.1939e-04 - val_loss: 6.3251e-05
# Epoch 37/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.2364e-04 - val_loss: 5.5755e-05
# Epoch 38/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.1255e-04 - val_loss: 6.1252e-05
# Epoch 39/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.1892e-04 - val_loss: 5.6246e-05
# Epoch 40/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.1152e-04 - val_loss: 5.3616e-05
# Epoch 41/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.1492e-04 - val_loss: 5.2703e-05
# Epoch 42/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.1300e-04 - val_loss: 5.3500e-05
# Epoch 43/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.0823e-04 - val_loss: 5.3252e-05
# Epoch 44/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.1596e-04 - val_loss: 5.2094e-05
# Epoch 45/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.1690e-04 - val_loss: 5.2098e-05
# Epoch 46/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.1254e-04 - val_loss: 5.1101e-05
# Epoch 47/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.1007e-04 - val_loss: 5.7854e-05
# Epoch 48/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.1125e-04 - val_loss: 5.1422e-05
# Epoch 49/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.1616e-04 - val_loss: 5.2229e-05
# Epoch 50/50
# 14/14 [==============================] - 16s 1s/step - loss: 1.1746e-04 - val_loss: 5.2001e-05

# %%
predicted_stock_price = model.predict(feature_test)
plot_results(predicted_stock_price,label_test, model = "LSTM")

# %%
predictions = predict_sequences_multiple(model, feature_test, Enrol_window, 15)
plot_results_multiple(predictions, label_test, 15, model = "LSTM")

# %%
import math
from sklearn.metrics import mean_squared_error
def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# %%
return_rmse(predicted_stock_price,label_test)
# Out:
# The root mean squared error is 0.007211204370815115.

# %%
modelGRU = Sequential()
modelGRU.add(GRU(60, return_sequences=True, input_shape=(feature_train.shape[1],1),activation='tanh'))
modelGRU.add(Dropout(0.2))
modelGRU.add(GRU(60, return_sequences=True,activation='tanh'))
modelGRU.add(Dropout(0.2))
modelGRU.add(GRU(units=60, return_sequences=False,activation='tanh'))
modelGRU.add(Dropout(0.2))
modelGRU.add(Dense(1, activation = "linear"))

modelGRU.compile(loss='mse', optimizer='adam')

print ('model compiled')
# Out:
# model compiled

# %%
c = modelGRU.fit(feature_train, label_train, batch_size=128, epochs=50, validation_data = (feature_test, label_test))
# Out:
# Epoch 1/50
# 14/14 [==============================] - 3s 241ms/step - loss: 0.0013 - val_loss: 3.1397e-04
# Epoch 2/50
# 14/14 [==============================] - 2s 174ms/step - loss: 4.3034e-04 - val_loss: 1.5262e-04
# Epoch 3/50
# 14/14 [==============================] - 3s 180ms/step - loss: 3.0332e-04 - val_loss: 1.1508e-04
# Epoch 4/50
# 14/14 [==============================] - 2s 178ms/step - loss: 2.5522e-04 - val_loss: 1.0661e-04
# Epoch 5/50
# 14/14 [==============================] - 2s 172ms/step - loss: 2.2638e-04 - val_loss: 1.2724e-04
# Epoch 6/50
# 14/14 [==============================] - 2s 175ms/step - loss: 2.3196e-04 - val_loss: 1.2111e-04
# Epoch 7/50
# 14/14 [==============================] - 2s 174ms/step - loss: 2.0503e-04 - val_loss: 1.0842e-04
# Epoch 8/50
# 14/14 [==============================] - 2s 175ms/step - loss: 2.0490e-04 - val_loss: 1.0729e-04
# Epoch 9/50
# 14/14 [==============================] - 2s 172ms/step - loss: 2.0711e-04 - val_loss: 9.1724e-05
# Epoch 10/50
# 14/14 [==============================] - 2s 177ms/step - loss: 2.0182e-04 - val_loss: 8.7872e-05
# Epoch 11/50
# 14/14 [==============================] - 3s 182ms/step - loss: 1.8987e-04 - val_loss: 9.1255e-05
# Epoch 12/50
# 14/14 [==============================] - 3s 180ms/step - loss: 1.7773e-04 - val_loss: 9.4324e-05
# Epoch 13/50
# 14/14 [==============================] - 3s 179ms/step - loss: 1.7270e-04 - val_loss: 8.5260e-05
# Epoch 14/50
# 14/14 [==============================] - 2s 176ms/step - loss: 1.6346e-04 - val_loss: 8.9323e-05
# Epoch 15/50
# 14/14 [==============================] - 2s 178ms/step - loss: 1.7418e-04 - val_loss: 1.1368e-04
# Epoch 16/50
# 14/14 [==============================] - 2s 177ms/step - loss: 1.7572e-04 - val_loss: 8.3459e-05
# Epoch 17/50
# 14/14 [==============================] - 2s 174ms/step - loss: 1.5810e-04 - val_loss: 8.8312e-05
# Epoch 18/50
# 14/14 [==============================] - 3s 184ms/step - loss: 1.5461e-04 - val_loss: 7.0312e-05
# Epoch 19/50
# 14/14 [==============================] - 2s 175ms/step - loss: 1.4726e-04 - val_loss: 7.4072e-05
# Epoch 20/50
# 14/14 [==============================] - 3s 181ms/step - loss: 1.6405e-04 - val_loss: 8.1687e-05
# Epoch 21/50
# 14/14 [==============================] - 3s 183ms/step - loss: 1.5311e-04 - val_loss: 1.0205e-04
# Epoch 22/50
# 14/14 [==============================] - 2s 177ms/step - loss: 1.4933e-04 - val_loss: 6.2845e-05
# Epoch 23/50
# 14/14 [==============================] - 2s 178ms/step - loss: 1.2797e-04 - val_loss: 7.3222e-05
# Epoch 24/50
# 14/14 [==============================] - 2s 177ms/step - loss: 1.3312e-04 - val_loss: 7.8102e-05
# Epoch 25/50
# 14/14 [==============================] - 3s 182ms/step - loss: 1.3787e-04 - val_loss: 6.7237e-05
# Epoch 26/50
# 14/14 [==============================] - 3s 179ms/step - loss: 1.2921e-04 - val_loss: 7.6585e-05
# Epoch 27/50
# 14/14 [==============================] - 2s 178ms/step - loss: 1.3308e-04 - val_loss: 6.5389e-05
# Epoch 28/50
# 14/14 [==============================] - 2s 177ms/step - loss: 1.2371e-04 - val_loss: 6.9785e-05
# Epoch 29/50
# 14/14 [==============================] - 3s 182ms/step - loss: 1.2579e-04 - val_loss: 6.0778e-05
# Epoch 30/50
# 14/14 [==============================] - 3s 193ms/step - loss: 1.2870e-04 - val_loss: 7.5156e-05
# Epoch 31/50
# 14/14 [==============================] - 3s 186ms/step - loss: 1.3140e-04 - val_loss: 5.3565e-05
# Epoch 32/50
# 14/14 [==============================] - 3s 185ms/step - loss: 1.2702e-04 - val_loss: 5.6921e-05
# Epoch 33/50
# 14/14 [==============================] - 3s 182ms/step - loss: 1.4447e-04 - val_loss: 5.6249e-05
# Epoch 34/50
# 14/14 [==============================] - 3s 182ms/step - loss: 1.4687e-04 - val_loss: 7.8499e-05
# Epoch 35/50
# 14/14 [==============================] - 3s 185ms/step - loss: 1.2821e-04 - val_loss: 5.3535e-05
# Epoch 36/50
# 14/14 [==============================] - 3s 183ms/step - loss: 1.1993e-04 - val_loss: 5.1486e-05
# Epoch 37/50
# 14/14 [==============================] - 3s 189ms/step - loss: 1.2048e-04 - val_loss: 5.2507e-05
# Epoch 38/50
# 14/14 [==============================] - 3s 184ms/step - loss: 1.2186e-04 - val_loss: 5.1160e-05
# Epoch 39/50
# 14/14 [==============================] - 2s 178ms/step - loss: 1.1285e-04 - val_loss: 6.9124e-05
# Epoch 40/50
# 14/14 [==============================] - 2s 176ms/step - loss: 1.1981e-04 - val_loss: 5.4845e-05
# Epoch 41/50
# 14/14 [==============================] - 3s 179ms/step - loss: 1.1360e-04 - val_loss: 5.1836e-05
# Epoch 42/50
# 14/14 [==============================] - 2s 175ms/step - loss: 1.1923e-04 - val_loss: 5.0900e-05
# Epoch 43/50
# 14/14 [==============================] - 3s 181ms/step - loss: 1.2979e-04 - val_loss: 9.8072e-05
# Epoch 44/50
# 14/14 [==============================] - 3s 188ms/step - loss: 1.2312e-04 - val_loss: 5.7842e-05
# Epoch 45/50
# 14/14 [==============================] - 3s 186ms/step - loss: 1.2027e-04 - val_loss: 5.8966e-05
# Epoch 46/50
# 14/14 [==============================] - 3s 181ms/step - loss: 1.1984e-04 - val_loss: 6.2288e-05
# Epoch 47/50
# 14/14 [==============================] - 2s 178ms/step - loss: 1.1939e-04 - val_loss: 5.1865e-05
# Epoch 48/50
# 14/14 [==============================] - 2s 178ms/step - loss: 1.1607e-04 - val_loss: 5.7861e-05
# Epoch 49/50
# 14/14 [==============================] - 2s 175ms/step - loss: 1.2211e-04 - val_loss: 4.9226e-05
# Epoch 50/50
# 14/14 [==============================] - 3s 185ms/step - loss: 1.1094e-04 - val_loss: 4.9193e-05

# %%
predicted_GRU_stock_price = modelGRU.predict(feature_test)
plot_results(predicted_GRU_stock_price,label_test, model = "GRU")

# %%
predictions_GRU = predict_sequences_multiple(modelGRU, feature_test, Enrol_window, 15)
plot_results_multiple(predictions_GRU, label_test, 15, model = "GRU")

# %%
return_rmse(predicted_GRU_stock_price,label_test)
# Out:
# The root mean squared error is 0.007013806443807682.

# %%
import numpy as np # linear algebra
from numpy import newaxis
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM, GRU
from keras.models import Sequential
from keras import optimizers
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

print ('import completed')
# Out:
# Using TensorFlow backend.
# import completed

# %%
Enrol_window = 60

print ('enrol window set to',Enrol_window )
# Out:
# enrol window set to 60

# %%
sc = MinMaxScaler(feature_range=(0,1))
def load_data(datasetname, column, seq_len, normalise_window):
    # A support function to help prepare datasets for an RNN/LSTM/GRU
    data = datasetname.loc[:,column]

    sequence_length = seq_len + 1
    result = []
    for index in range(len(data) - sequence_length):
        result.append(data[index: index + sequence_length])
    
    if normalise_window:
        #result = sc.fit_transform(result)
        result = normalise_windows(result)

    result = np.array(result)

    #Last 10% is used for validation test, first 90% for training
    row = round(0.9 * result.shape[0])
    train = result[:int(row), :]
    np.random.shuffle(train)
    x_train = train[:, :-1]
    y_train = train[:, -1]
    x_test = result[int(row):, :-1]
    y_test = result[int(row):, -1]

    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))  

    return [x_train, y_train, x_test, y_test]

def normalise_windows(window_data):
    # A support function to normalize a dataset
    normalised_data = []
    for window in window_data:
        normalised_window = [((float(p) / float(window[0])) - 1) for p in window]
        normalised_data.append(normalised_window)
    return normalised_data

def predict_sequence_full(model, data, window_size):
    #Shift the window by 1 new prediction each time, re-run predictions on new window
    curr_frame = data[0]
    predicted = []
    for i in range(len(data)):
        predicted.append(model.predict(curr_frame[newaxis,:,:])[0,0])
        curr_frame = curr_frame[1:]
        curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
    return predicted

def predict_sequences_multiple(model, data, window_size, prediction_len):
    #Predict sequence of <prediction_len> steps before shifting prediction run forward by <prediction_len> steps
    prediction_seqs = []
    for i in range(int(len(data)/prediction_len)):
        curr_frame = data[i*prediction_len]
        predicted = []
        for j in range(prediction_len):
            predicted.append(model.predict(curr_frame[newaxis,:,:])[0,0])
            curr_frame = curr_frame[1:]
            curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
        prediction_seqs.append(predicted)
    return prediction_seqs


def plot_results(predicted_data, true_data): 
    fig = plt.figure(facecolor='white', figsize = (15,8)) 
    ax = fig.add_subplot(111) 
    ax.plot(true_data, label='Evolutie reala') 
    ax.set_title("Testare Model GRU SMI")
    plt.plot(predicted_data, label='Previziune') 
    plt.legend() 
    plt.show() 
    
def plot_results_multiple(predicted_data, true_data, prediction_len):
    fig = plt.figure(facecolor='white', figsize = (15,8))
    ax = fig.add_subplot(111)
    ax.plot(true_data, label='Evolutia observata')
    ax.set_title("Previziune GRU SMI")
    #Pad the list of predictions to shift it in the graph to it's correct start
    for i, data in enumerate(predicted_data):
        padding = [None for p in range(i * prediction_len)]
        plt.plot(padding + data, label='Predictie')
        plt.legend(loc = "lower right", fontsize = 9)
    plt.show()

print ('Support functions defined')
# Out:
# Support functions defined

# %%
dataset = pd.read_csv('SMI.csv', index_col='Date', parse_dates=['Date'])
dataset.head()
# Out:
#               Close     Open     High      Low    Vol. Change % Name
# Date
# 2012-02-01  6069.91  5984.11  6077.40  5979.22  55.10M    1.67%  SMI
# 2012-02-02  6064.41  6083.36  6085.11  6038.53  51.60M   -0.09%  SMI
# 2012-02-03  6153.31  6062.44  6158.11  6046.99  55.58M    1.47%  SMI
# 2012-02-06  6147.03  6126.54  6150.80  6103.77  40.33M   -0.10%  SMI
# 2012-02-07  6157.59  6143.40  6158.50  6114.68  51.76M    0.17%  SMI

# %%
feature_train, label_train, feature_test, label_test = load_data(dataset, 'Close', Enrol_window, True)

dataset["Close"][:'2019'].plot(figsize=(16,4),legend=True)
dataset["Close"]['2019':].plot(figsize=(16,4),legend=True) # 10% is used for thraining data which is approx 2017 data
plt.legend(['Training set (First 90%, approx before 2017)','Test set (Last 10%, approax 2017 and beyond)'])
plt.title('SMI stock price')
plt.show()

# %%
# The same LSTM model I would like to test, lets see if the sinus prediction results can be matched
# Note: replace LSTM with GRU or RNN if you want to try those

model = Sequential()
model.add(LSTM(256, return_sequences=True, input_shape=(feature_train.shape[1],1)))
model.add(Dropout(0.2))
model.add(LSTM(256, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=64, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1, activation = "linear"))

model.compile(loss='mse', optimizer='adam')

print ('model compiled')
# Out:
# model compiled

# %%
b = model.fit(feature_train, label_train, batch_size=128, epochs=50, validation_data = (feature_test, label_test))
# Out:
# Train on 1748 samples, validate on 194 samples
# Epoch 1/50
# 1748/1748 [==============================] - 3s 2ms/step - loss: 9.9779e-04 - val_loss: 1.8539e-04
# Epoch 2/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 4.5503e-04 - val_loss: 1.5518e-04
# Epoch 3/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 3.7256e-04 - val_loss: 1.5268e-04
# Epoch 4/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 3.2747e-04 - val_loss: 1.5923e-04
# Epoch 5/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 3.1468e-04 - val_loss: 1.3824e-04
# Epoch 6/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 2.8020e-04 - val_loss: 1.9906e-04
# Epoch 7/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 2.7235e-04 - val_loss: 1.2679e-04
# Epoch 8/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 2.5601e-04 - val_loss: 1.5317e-04
# Epoch 9/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 2.4299e-04 - val_loss: 1.5884e-04
# Epoch 10/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 2.2995e-04 - val_loss: 1.7427e-04
# Epoch 11/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 2.2558e-04 - val_loss: 1.4119e-04
# Epoch 12/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 2.2266e-04 - val_loss: 1.0286e-04
# Epoch 13/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.9563e-04 - val_loss: 1.0139e-04
# Epoch 14/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.9632e-04 - val_loss: 9.5449e-05
# Epoch 15/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.9393e-04 - val_loss: 9.4964e-05
# Epoch 16/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.8677e-04 - val_loss: 9.0041e-05
# Epoch 17/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.9017e-04 - val_loss: 9.7915e-05
# Epoch 18/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.8370e-04 - val_loss: 9.3654e-05
# Epoch 19/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.8333e-04 - val_loss: 8.6161e-05
# Epoch 20/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.6696e-04 - val_loss: 8.2674e-05
# Epoch 21/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.6836e-04 - val_loss: 7.9840e-05
# Epoch 22/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.6640e-04 - val_loss: 7.8122e-05
# Epoch 23/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.5040e-04 - val_loss: 8.1778e-05
# Epoch 24/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.4736e-04 - val_loss: 7.3246e-05
# Epoch 25/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.5181e-04 - val_loss: 7.2322e-05
# Epoch 26/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.4210e-04 - val_loss: 7.0071e-05
# Epoch 27/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.4082e-04 - val_loss: 7.4491e-05
# Epoch 28/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.3817e-04 - val_loss: 6.7191e-05
# Epoch 29/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.3769e-04 - val_loss: 8.7091e-05
# Epoch 30/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.2670e-04 - val_loss: 9.1680e-05
# Epoch 31/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.4280e-04 - val_loss: 7.2656e-05
# Epoch 32/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.3056e-04 - val_loss: 6.7974e-05
# Epoch 33/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.2936e-04 - val_loss: 5.9695e-05
# Epoch 34/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.1624e-04 - val_loss: 5.9022e-05
# Epoch 35/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.2162e-04 - val_loss: 6.2916e-05
# Epoch 36/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.2619e-04 - val_loss: 6.0958e-05
# Epoch 37/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.3118e-04 - val_loss: 6.3796e-05
# Epoch 38/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.2158e-04 - val_loss: 5.7070e-05
# Epoch 39/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.1590e-04 - val_loss: 5.8352e-05
# Epoch 40/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.1440e-04 - val_loss: 6.9881e-05
# Epoch 41/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.1500e-04 - val_loss: 5.9099e-05
# Epoch 42/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.1559e-04 - val_loss: 7.1576e-05
# Epoch 43/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.1337e-04 - val_loss: 6.6085e-05
# Epoch 44/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.1813e-04 - val_loss: 5.6741e-05
# Epoch 45/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.1205e-04 - val_loss: 5.1313e-05
# Epoch 46/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.0948e-04 - val_loss: 5.2449e-05
# Epoch 47/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.1366e-04 - val_loss: 5.2164e-05
# Epoch 48/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.0525e-04 - val_loss: 5.1581e-05
# Epoch 49/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.1832e-04 - val_loss: 5.3367e-05
# Epoch 50/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.0732e-04 - val_loss: 5.2491e-05

# %%
# plot history
from matplotlib import pyplot
pyplot.plot(b.history['loss'], label='train')
pyplot.plot(b.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
predicted_stock_price = model.predict(feature_test)
plot_results(predicted_stock_price,label_test)

# %%
predictions = predict_sequences_multiple(model, feature_test, Enrol_window, 15)
plot_results_multiple(predictions, label_test, 15)

# %%
import math
from sklearn.metrics import mean_squared_error
def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# %%
return_rmse(predicted_stock_price,label_test)
# Out:
# The root mean squared error is 0.007245053742780608.

# %%
modelGRU = Sequential()
modelGRU.add(GRU(60, return_sequences=True, input_shape=(feature_train.shape[1],1),activation='tanh'))
modelGRU.add(Dropout(0.2))
modelGRU.add(GRU(60, return_sequences=True,activation='tanh'))
modelGRU.add(Dropout(0.2))
modelGRU.add(GRU(units=60, return_sequences=False,activation='tanh'))
modelGRU.add(Dropout(0.2))
modelGRU.add(Dense(1, activation = "linear"))

modelGRU.compile(loss='mse', optimizer='adam')

print ('model compiled')
# Out:
# model compiled

# %%
c = modelGRU.fit(feature_train, label_train, batch_size=128, epochs=50, validation_data = (feature_test, label_test))
# Out:
# Train on 1748 samples, validate on 194 samples
# Epoch 1/50
# 1748/1748 [==============================] - 3s 2ms/step - loss: 0.0012 - val_loss: 1.6603e-04
# Epoch 2/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 3.5105e-04 - val_loss: 1.2721e-04
# Epoch 3/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 3.1565e-04 - val_loss: 1.2283e-04
# Epoch 4/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 2.7005e-04 - val_loss: 1.3671e-04
# Epoch 5/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 2.4380e-04 - val_loss: 1.0537e-04
# Epoch 6/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 2.2912e-04 - val_loss: 1.0186e-04
# Epoch 7/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 2.2097e-04 - val_loss: 1.0873e-04
# Epoch 8/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 2.3716e-04 - val_loss: 1.3996e-04
# Epoch 9/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 2.1212e-04 - val_loss: 1.0860e-04
# Epoch 10/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 2.0790e-04 - val_loss: 1.1811e-04
# Epoch 11/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.9573e-04 - val_loss: 9.1706e-05
# Epoch 12/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.8110e-04 - val_loss: 8.5409e-05
# Epoch 13/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.7027e-04 - val_loss: 8.4982e-05
# Epoch 14/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.7970e-04 - val_loss: 8.0983e-05
# Epoch 15/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.9487e-04 - val_loss: 7.8541e-05
# Epoch 16/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.6492e-04 - val_loss: 1.0994e-04
# Epoch 17/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.6400e-04 - val_loss: 7.6928e-05
# Epoch 18/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.6083e-04 - val_loss: 7.4387e-05
# Epoch 19/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.6566e-04 - val_loss: 7.2533e-05
# Epoch 20/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.5828e-04 - val_loss: 8.7421e-05
# Epoch 21/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.5255e-04 - val_loss: 7.3492e-05
# Epoch 22/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.4770e-04 - val_loss: 8.3430e-05
# Epoch 23/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.4873e-04 - val_loss: 6.7247e-05
# Epoch 24/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.4279e-04 - val_loss: 7.0132e-05
# Epoch 25/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.3991e-04 - val_loss: 6.4290e-05
# Epoch 26/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.4251e-04 - val_loss: 8.9266e-05
# Epoch 27/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.4446e-04 - val_loss: 6.3146e-05
# Epoch 28/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.3290e-04 - val_loss: 5.9708e-05
# Epoch 29/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.3037e-04 - val_loss: 6.0891e-05
# Epoch 30/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.3746e-04 - val_loss: 6.2601e-05
# Epoch 31/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.3241e-04 - val_loss: 5.5694e-05
# Epoch 32/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.2124e-04 - val_loss: 5.8266e-05
# Epoch 33/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.2083e-04 - val_loss: 5.4594e-05
# Epoch 34/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.2702e-04 - val_loss: 5.4189e-05
# Epoch 35/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.3032e-04 - val_loss: 5.3374e-05
# Epoch 36/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.3669e-04 - val_loss: 5.6928e-05
# Epoch 37/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.1162e-04 - val_loss: 5.3187e-05
# Epoch 38/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.1781e-04 - val_loss: 5.3836e-05
# Epoch 39/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.2549e-04 - val_loss: 5.7680e-05
# Epoch 40/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.3596e-04 - val_loss: 5.5869e-05
# Epoch 41/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.2289e-04 - val_loss: 5.1123e-05
# Epoch 42/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.3563e-04 - val_loss: 5.8995e-05
# Epoch 43/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.2877e-04 - val_loss: 5.3307e-05
# Epoch 44/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.1767e-04 - val_loss: 5.0728e-05
# Epoch 45/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.1529e-04 - val_loss: 5.0979e-05
# Epoch 46/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.1611e-04 - val_loss: 5.2525e-05
# Epoch 47/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.2161e-04 - val_loss: 5.0206e-05
# Epoch 48/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.2245e-04 - val_loss: 4.9930e-05
# Epoch 49/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.1322e-04 - val_loss: 5.6769e-05
# Epoch 50/50
# 1748/1748 [==============================] - 2s 1ms/step - loss: 1.2365e-04 - val_loss: 5.2873e-05

# %%
predicted_GRU_stock_price = modelGRU.predict(feature_test)
plot_results(predicted_GRU_stock_price,label_test)

# %%
predictions_GRU = predict_sequences_multiple(modelGRU, feature_test, Enrol_window, 15)
plot_results_multiple(predictions_GRU, label_test, 15)

# %%
return_rmse(predicted_GRU_stock_price,label_test)
# Out:
# The root mean squared error is 0.007271366450226152.
